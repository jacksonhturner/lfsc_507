# %% [markdown]
# ### Exercise 6.2

# %%
import random as rand

def silly_calculator(first_number,second_number):
    sum_number = first_number + second_number
    fun_phrase = ["Wowza!","Yippee!","Yowee!","Heavens to Besty!","Gadzooks!","Egad!","Holy moly me oh my!"]
    print("The sum of your two numbers is " + str(sum_number) + ". " + rand.choice(fun_phrase))

silly_calculator(1,2.878)
# Out:
# The sum of your two numbers is 3.878. Yowee!

# %% [markdown]
# ### Exercise 6.3

# %%
def boring_calculator(first_number,second_number):
    return (first_number + second_number)

boring_calculator(2,6)
# Out:
# 8

# %% [markdown]
# ### Exercise 6.4

# %%
genes1 = ['ZEB1', 'CAV1', 'CTNNB1', 'CTNNB1', 'CTNNB1', 'CTNND1', 'EGFR', 'ACTR3', 'ANAPC7', 'ARHGAP32', 'ARVCF', 'CA9', 'CASP3', 'CASP8', 'CBLL1', 'cdh1', 'CSE1L', 'CSNK2A1', 'CTNNA1', 'CTNNB1', 'CTNND1', 'CTNND2', 'EGFR', 'ERBIN', 'EZR', 'GNA12', 'GNA13', 'GSK3B', 'HDAC1', 'HDAC2', 'IQGAP1', 'IRS1', 'ITGAE', 'ITGB7', 'JUP', 'NDRG1', 'NEDD9', 'PKD1', 'PPP1CA', 'PSEN1', 'PTPN14', 'PTPRF', 'PTPRM', 'RAB8B', 'RRM2', 'VCL', 'AAK1', 'ABCF3', 'ABI1', 'ABLIM1', 'ABLIM3', 'ACADVL', 'ACBD3', 'ACTG1', 'ACTN1', 'ACTN4', 'ADAM17', 'ADAM9', 'ADCY9', 'ADD1', 'ADD3', 'ADGRL2', 'AFDN', 'AGFG1', 'AHNAK', 'AHSA1', 'AJAP1', 'ALDOA', 'ANK3', 'ANLN', 'ANP32B', 'ANXA1', 'ANXA2', 'ANXA4', 'AP2M1', 'ARFGAP2', 'ARFIP1', 'ARFIP2', 'ARGLU1', 'ARHGAP1', 'ARHGAP18', 'ARHGAP21', 'ARHGAP23', 'ARHGAP29', 'ARHGAP32', 'ARHGAP5', 'ARHGDIB', 'ARHGEF12', 'ARHGEF16', 'ARPC2', 'ARPIN', 'ARVCF', 'ASAP1', 'ATIC', 'ATP2B1', 'ATP2B4', 'ATXN2L', 'BAG3', 'BAIAP2', 'BAIAP2L1', 'BCL2L2', 'BMPR2', 'BRCA1', 'BSG', 'BZW1', 'BZW2', 'C1QBP', 'C1orf116', 'C1orf198', 'C1orf35', 'C6orf132', 'CA9', 'CALD1', 'CAMK1D', 'CANT1', 'CAPG', 'CAPS', 'CAPZA1', 'CAPZB', 'CARMIL1', 'CASKIN2', 'CASP3', 'CAST', 'CBL', 'CBLL1', 'CC2D1A', 'CCDC120', 'CCDC43', 'CCDC85C', 'CCNB2', 'CCS', 'CCSER2', 'CCT8', 'CD2AP', 'CD99', 'CDC27', 'CDC42', 'CDC42EP1', 'CDC42EP4', 'CDCA3', 'CDH1', 'CDH3', 'CDKL5', 'CEMIP2', 'CFTR', 'CGN', 'CHMP2B', 'CHMP4B', 'CHMP5', 'CIAPIN1', 'CIP2A', 'CKAP5', 'CLIC1', 'CLINT1', 'CLMN', 'CNN2', 'CNN3', 'COBLL1', 'COL17A1', 'COPG2', 'CORO1B', 'CREBBP', 'CRK', 'CRKL', 'CRYAB', 'CRYBG1', 'CSE1L', 'CSNK1A1', 'CSNK1D', 'CTNNA1', 'CTNNA2', 'CTNNA3', 'CTNNB1', 'CTNND1', 'CTSB', 'CTTN', 'CXADR', 'DAAM1', 'DAB2IP', 'DAG1', 'DBN1', 'DBNL', 'DCAF4', 'DDR1', 'DDR2', 'DDX39B', 'DDX3X', 'DDX6', 'DENND4C', 'DHX29', 'DIAPH3', 'DLG1', 'DLG5', 'DNAJB1', 'DOCK9', 'DSC3', 'DSG2', 'DST', 'DVL3', 'E2F1', 'EBNA1BP2', 'ECT2', 'EEF1A1', 'EEF1D', 'EEF1G', 'EEF2', 'EFHD2', 'EFR3A', 'EGFR', 'EHBP1', 'EHBP1L1', 'EHD1', 'EHD4', 'EIF2A', 'EIF2S3', 'EIF3E', 'EIF4B', 'EIF4G1', 'EIF4G2', 'EIF4H', 'EIF5', 'EIF5A', 'ELFN2', 'ELMOD3', 'ELP4', 'EMD', 'ENO1', 'EP300', 'EPB41', 'EPB41L1', 'EPB41L3', 'EPB41L4B', 'EPHA2', 'EPN2', 'EPN3', 'EPS15', 'EPS15L1', 'EPS8L1', 'EPS8L2', 'ERBB2', 'ERBB3', 'ERBIN', 'ERC1', 'ESR2', 'ESYT1', 'ESYT2', 'EVPL', 'EXOC3', 'EZR', 'F11R', 'FAM110A', 'FAM110C', 'FAM126A', 'FAM126B', 'FAM171B', 'FAM83B', 'FAM83H', 'FAM91A1', 'FASN', 'FER', 'FERMT1', 'FGFR1', 'FLNA', 'FLNB', 'FLOT1', 'FMN1', 'FMNL2', 'FNBP1L', 'FRS2', 'FSCN1', 'FTH1', 'FYN', 'GAB1', 'GAPVD1', 'GCN1', 'GCOM1', 'GGA3', 'GIGYF2', 'GIPC1', 'GLOD4', 'GM2A', 'GMNN', 'GNA12', 'GNA13', 'GOLGA2', 'GOLGA3', 'GOLGA5', 'GOLGA8B', 'GOLGB1', 'GORASP2', 'GPC1', 'GPRC5A', 'GPRIN1', 'GSK3B', 'GSPT1', 'H1-10', 'H3C1', 'HCFC1', 'HDAC1', 'HDAC2', 'HDLBP', 'HECTD1', 'HLA-C', 'HNRNPK', 'HSP90AA1', 'HSP90AB1', 'HSPA1A', 'HSPA5', 'HSPA8', 'HSPA9', 'HSPD1', 'IDH1', 'IGBP1', 'IGF2R', 'IGHA1', 'IL6ST', 'ILK', 'INAVA', 'INPPL1', 'IQGAP1', 'IRAK1', 'IST1', 'ISYNA1', 'ITGA6', 'ITGAE', 'ITGB1', 'ITPRID2', 'IVL', 'JCAD', 'JPT1', 'JPT2', 'JUP', 'KANK2', 'KCNN4', 'KDF1', 'KEAP1', 'KIAA1217', 'KIAA1522', 'KIAA1671', 'KIDINS220', 'KIF5B', 'KLC2', 'KLF4', 'KRAS', 'KRT1', 'KRT18', 'KRT8', 'KRT9', 'KTN1', 'LAD1', 'LARP1', 'LASP1', 'LBR', 'LDHA', 'LGALS3BP', 'LIMA1', 'LIMCH1', 'LLGL1', 'LMNA', 'LMO7', 'LPP', 'LRATD2', 'LRRC57', 'LRRC59', 'LRRC7', 'LRRFIP1', 'LSR', 'LUZP1', 'LYPLA2', 'LZTS2', 'MACC1', 'MACF1', 'MACROH2A1', 'MAGI1', 'MAGI3', 'MAP4', 'MAPRE1', 'MARCKS', 'MARK2', 'MARK3', 'MARVELD2', 'MAVS', 'MB21D2', 'MDM2', 'MET', 'MICALL1', 'MINK1', 'MPP7', 'MPRIP', 'MPZL1', 'MRE11', 'MRTFB', 'MYH9', 'MYO1B', 'MYO6', 'MYO7A', 'N4BP1', 'NAV2', 'NCK1', 'NCK2', 'NDRG1', 'NDRG2', 'NEBL', 'NECTIN1', 'NECTIN2', 'NECTIN4', 'NF2', 'NFE2L2', 'NFKBIE', 'NGDN', 'NHS', 'NHSL1', 'NIBAN2', 'NIPSNAP1', 'NIPSNAP2', 'NKD2', 'NLRP2', 'NOP56', 'NOTCH1', 'NOTCH2', 'NOTCH3', 'NSFL1C', 'NUDC', 'NUDT5', 'NUMB', 'NUMBL', 'NUP214', 'OCLN', 'OLA1', 'PACSIN2', 'PAG1', 'PAICS', 'PAK2', 'PAK4', 'PAK6', 'PALM2AKAP2', 'PALM3', 'PARD3', 'PARK7', 'PARVA', 'PATJ', 'PCBP1', 'PCBP2', 'PCDH1', 'PCDHGC3', 'PCMT1', 'PDAP1', 'PDLIM1', 'PDLIM5', 'PDLIM7', 'PDXDC1', 'PEAK1', 'PFKP', 'PFN1', 'PGRMC2', 'PHACTR2', 'PHACTR4', 'PHLDB2', 'PI4KA', 'PICALM', 'PIP5K1C', 'PKD1', 'PKM', 'PKN2', 'PKP2', 'PKP3', 'PKP4', 'PLCB3', 'PLEC', 'PLEKHA1', 'PLEKHA2', 'PLEKHA5', 'PLEKHA6', 'PLEKHA7', 'PLEKHO2', 'PLIN3', 'PLSCR1', 'PLSCR3', 'POF1B', 'POLR2E', 'PPFIBP1', 'PPL', 'PPME1', 'PPP1CA', 'PPP1R13B', 'PPP1R13L', 'PPP1R18', 'PPP1R37', 'PRDX1', 'PRDX6', 'PROM2', 'PSEN1', 'PSMB6', 'PTPN1', 'PTPRD', 'PTPRG', 'PTPRJ', 'PTPRM', 'PTPRS', 'PUF60', 'PXN', 'RAB10', 'RAB11B', 'RAB1A', 'RAB8B', 'RACK1', 'RAD17', 'RAI14', 'RAN', 'RANBP1', 'RANGAP1', 'RAPH1', 'RARS1', 'RB1CC1', 'RDX', 'RELL1', 'RNF2', 'RNF43', 'RPL14', 'RPL15', 'RPL23A', 'RPL24', 'RPL29', 'RPL34', 'RPL36A', 'RPL36AL', 'RPL37', 'RPL6', 'RPL7A', 'RPS2', 'RPS26', 'RSL1D1', 'RTN4', 'RUVBL1', 'S100A11', 'S100P', 'SBSN', 'SCARB1', 'SCEL', 'SCRIB', 'SCYL1', 'SCYL2', 'SDCBP', 'SEC24B', 'SEPTIN2', 'SEPTIN7', 'SEPTIN9', 'SERBP1', 'SET', 'SFN', 'SH3D19', 'SH3GL1', 'SH3GLB1', 'SH3GLB2', 'SH3KBP1', 'SH3PXD2B', 'SH3RF1', 'SHANK2', 'SHB', 'SHROOM3', 'SHTN1', 'SIPA1L3', 'SIRPA', 'SKP2', 'SLC12A2', 'SLC16A3', 'SLC1A5', 'SLC2A14', 'SLC30A1', 'SLC38A1', 'SLC3A2', 'SLC4A7', 'SLC9A1', 'SLC9A3R1', 'SLC9A3R2', 'SLK', 'SMAD7', 'SNAP23', 'SNAP25', 'SNAP29', 'SND1', 'SNX1', 'SNX2', 'SNX5', 'SNX9', 'SORBS1', 'SPAG1', 'SPECC1', 'SPRED1', 'SPRR3', 'SPTAN1', 'SPTBN1', 'SPTBN2', 'SRC', 'SRCIN1', 'SRGAP2', 'SSH3', 'STAT1', 'STAT2', 'STEAP3', 'STIM1', 'STK24', 'STK38', 'STX4', 'STX5', 'STXBP6', 'SVIL', 'SWAP70', 'SYAP1', 'SYNJ1', 'SYNJ2', 'SYT7', 'TAGLN2', 'TANC1', 'TBC1D10A', 'TBC1D10B', 'TBC1D22B', 'TENM3', 'TES', 'TGFB1', 'TGM2', 'TJP1', 'TJP2', 'TLN1', 'TMEM199', 'TMEM51', 'TMEM87A', 'TMOD3', 'TMPO', 'TNKS1BP1', 'TP53BP2', 'TPD52', 'TPD52L2', 'TRIM25', 'TRIM29', 'TRIP11', 'TRIP6', 'TTC7A', 'TTK', 'TTN', 'TUBB', 'TUBB4B', 'TWF1', 'TWF2', 'TXNDC9', 'UACA', 'UBAP2', 'UBC', 'UBFD1', 'UCHL3', 'UHRF1', 'UL97', 'UNC45A', 'USO1', 'USP15', 'USP43', 'USP6NL', 'USP8', 'USP9X', 'UTRN', 'VAMP3', 'VAPA', 'VAPB', 'VASN', 'VASP', 'VCL', 'VCPIP1', 'VEZT', 'VSIG10L', 'WASF2', 'WIPF2', 'WWOX', 'XRCC5', 'XRN1', 'YAP1', 'YES1', 'YKT6', 'YWHAB', 'YWHAE', 'YWHAZ', 'ZC3H15', 'ZC3HAV1', 'ZDHHC5', 'ZFYVE16', 'ZG16B', 'ZNF185', 'ZYX']
genes2 = ['egfr', 'JUP', 'CTNNB1', 'CDH1', 'CDH1', 'EZR', 'ctnnd1', 'VCL', 'SRC', 'ANAPC11', 'CDC27', 'HSPA1B', 'SKP2', 'PIP5K1C', 'ECT2', 'IQGAP1', 'NEDD9', 'CSE1L', 'CBLL1', 'CTNNA1', 'NDRG1', 'PPP1CA', 'ANAPC7', 'HDAC2', 'PSEN1', 'MAGI1', 'CFTR', 'PLEKHA7']

def compare_genes(list1,list2):
    list1 = [i.upper() for i in list1]
    list2 = [i.upper() for i in list2]
    set1 = set(list1)
    set2 = set(list2)
    set1_dif = (set1.difference(set2))
    set2_dif = (set2.difference(set1))
    union_sets = set1.union(set2)
    intersection_sets = set1.intersection(set2)
    print("Disclaimer: genes in the list of gene inputs are capitalized in the outputs of this function. Enjoy!" + "\n")
    print("The genes present in the first list of genes and not the second are as follows:",)
    print(*set1_dif, sep = ", ")
    print("")
    print("The genes present in the second list of genes and not the first are as follows:")
    print(*set2_dif, sep = ", ")
    print("")
    print("The genes present in either list of genes are as follows:")
    print(*union_sets, sep = ", ")
    print("")
    print("The genes present in both lists of genes are as follows:")
    print(*intersection_sets, sep = ", ")

compare_genes(genes1,genes2)
# Out:
# Disclaimer: genes in the list of gene inputs are capitalized in the outputs of this function. Enjoy!
#
# The genes present in the first list of genes and not the second are as follows:
# ...
